# %% [markdown]
# Dataset

# %%
student_name = [ "Amara","Ben","Chloe","David","Eva","Farai","Grace","Hassan"]
age=(19,21,20,22,19,23,20,21)
subject= ["Math","Science","Math","English","Science","English","Math","Science"]
score=[72,55,88,45,91,63,50,77]
passed=[True,False,True,False,True,True,False,True]

# %%
student_name = "Amara"
age = 19
subject = "Math"
score = 72
passed = True

# %%
1.1
type(student_name)
print(type(student_name))

type(age)
print(type(age))

type(score)
print(type(score))

type(passed)
print(type(passed))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>

# %%
# 1.2
type(score)
type(passed)
print(type(score))
print(type(passed))
# Out:
# <class 'int'>
# <class 'bool'>

# %%
# 1.3
final_mark = (72/100)*150
print(final_mark)
type(final_mark)
print(type(final_mark))
# Out:
# 108.0
# <class 'float'>

# %%
# 2.1
student_name = [ "Amara","Ben","Chloe","David","Eva","Farai","Grace","Hassan"]
print(student_name [0])
print(student_name [-1])
print(student_name [2:5])
len(student_name)
print(len(student_name))
# Out:
# Amara
# Hassan
# ['Chloe', 'David', 'Eva']
# 8

# %%
# 2.2
score=[72,55,88,45,91,63,50,77]
print(score [0])
print(score [4])
result= score[0]+score[4]
print(result)
# Out:
# 72
# 91
# 163

# %%
# 2.3
hassan = {"student_names": "Hassan",
"age": 21, 
"subject": "Science",
"score": 77,
"passed": True}
new_score= 77 +10
print(subject)
print(new_score)
print(passed)
# Out:
# Math
# 87
# True

# %%
# 2.4
students = [
    {"name": "Amara"},
    {"name": "Ben"},
    {"name": "Chloe"},
    {"name": "David"}
]

print(students[0]["name"])
print(students[1]["name"])
print(len(students))
# Out:
# Amara
# Ben
# 4

# %%
# 3.1
name ="Amara"
age = 19
subject= 'Math'
score= 72
passed= True

if score > 60:
    print('true')
else:
    print('false')
if  age == 20:
    print('true')
else:
    print('false')
if subject != "Science": 
    print('true')
else:
    print('false')
if score >= 72:
    print('true')
else:
    print('false')
# Out:
# true
# false
# true
# true

# %%
# 3.2
name ="Amara"
age = 19
subject= 'Math'
score= 72
passed= True


if score > 60 and passed == True:
    print('true')
else:
    print('false')
if age < 18 or score > 70: 
    print('true')
else:
    print('false')
if not passed: 
    print('true')
else:
    print('false')
if score > 80 and subject == "Math":
    print('true')
else:
    print('false')
# Out:
# true
# true
# false
# false

# %%
# 3.3.1
score=91
if score >= 75:
    print("Distinction")
elif score>= 50 and score<= 74:
    print('Pass')
elif score <50:
    print('Fail')
else:
    print('Invalid')


print(score)
# Out:
# Distinction
# 91

# %%
# 3.3.2
score=72
if score >= 75:
    print("Distinction")
elif score>= 50 and score<= 74:
    print('Pass')
elif score <50:
    print('Fail')
else:
    print('Invalid')


print(score)
# Out:
# Pass
# 72

# %%
# 3.3.3
score=45
if score >= 75:
    print("Distinction")
elif score>= 50 and score<= 74:
    print('Pass')
elif score <50:
    print('Fail')
else:
    print('Invalid')


print(score)
# Out:
# Fail
# 45

# %%
# 3.4.1
# Name: Amara
score = 72
subject = "Math"

if score > 60 and subject == "Math":
    print("Math high achiever")
else:
    print("Does not meet criteria")
# Out:
# Math high achiever

# %%
#3.4.2
# Name:Ben
score= 55
subject='Science'

if score > 60 and subject =="Math":
    print("Math high achiever")
else:
    print("Does not meet criteria")
# Out:
# Does not meet criteria
